# %% [markdown]
# # import libraries

# %%
import numpy as np
import pandas as pd
import pymysql
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix
import matplotlib.pyplot as plt
from drive_and_win_bib import *

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ### fetch the database

# %%
try:
#fetch the data from the serveur   
    print("tentative d'access")
    cnx=pymysql.connect(host='51.77.149.46',user='djagora',passwd='djagora123@student',db='djagora_student1',charset='utf8mb4',cursorclass=pymysql.cursors.DictCursor, read_timeout=30)
    cursor = cnx.cursor()
    print(cursor)
    data=pd.read_sql_query("SELECT * FROM data",cnx)
    print("connexion to database successful")
except:
#if serveur connection failed fetch a local version of the database
    print("connexion to local database")
    data = pd.read_csv('./data01122020.csv', sep=',',header=0)
    data = pd.DataFrame(data)
    data.columns=['CIN', 'latitude', 'longitude', 'Speed','RPM','ENGINE_LOAD','AmbientAirTemp','ThrottlePos', 'insFuel','X','Y','Z','zone','time']
data.head(10)
# Out:
# tentative d'access
# <pymysql.cursors.DictCursor object at 0x000002005A8B7EE0>
# connexion to database successful
#        CIN   altitude  longitude SPEED ENGINE_RPM ENGINE_LOAD AmbientAirTemp  \
# 0  6023226  35.081856   9.869760    8       1495        null           null
# 1  6023226  35.081887   9.869902   20       2810       40,4%            36C
# 2  6023226  35.081886   9.870205   26       2116       83,5%            36C
# 3  6023226  35.081931   9.870459   37       1828       64,7%            36C
# 4  6023226  35.081950   9.871037   41       2019       64,7%            36C
# 5  6023226  35.081988   9.871456   44       2173       61,6%            36C
# 6  6023226  35.082021   9.871924   42       2035        1,6%            36C
# 7  6023226  35.082140   9.872353   36       1805       94,1%            36C
# 8  6023226  35.082202   9.872727   43       2049       12,9%            36C
# 9  6023226  35.082236   9.873162   35       1706        0,0%            36C
#
#   ThrottlePos insFuel  valX  valY  valZ       zone                time
# 0        null    None   NaN   NaN   NaN  Nationale 2020-07-05 21:13:09
# 1       23,9%    None   NaN   NaN   NaN  Nationale 2020-07-05 21:13:12
# 2       33,7%    None   NaN   NaN   NaN  Nationale 2020-07-05 21:13:16
# 3       25,9%    None   NaN   NaN   NaN  Nationale 2020-07-05 21:13:19
# 4       26,3%    None   NaN   NaN   NaN  Nationale 2020-07-05 21:13:22
# 5       27,5%    None   NaN   NaN   NaN  Nationale 2020-07-05 21:13:26
# 6       16,5%    None   NaN   NaN   NaN  Nationale 2020-07-05 21:13:29
# 7       88,2%    None   NaN   NaN   NaN  Nationale 2020-07-05 21:13:34
# 8       16,5%    None   NaN   NaN   NaN  Nationale 2020-07-05 21:13:37
# 9       16,1%    None   NaN   NaN   NaN  Nationale 2020-07-05 21:13:40

# %% [markdown]
# ### Clean database from comments

# %%
data = data.drop(['insFuel'],axis=1)
data = datacleaning_comment (data)

# %% [markdown]
# ### Transform database to numbers

# %%
def convert_to_number (data):
    data['time'] =  pd.to_datetime(data['time'])
    data = data.convert_dtypes(convert_string=False)
    
    dataconv =  data.apply(pd.to_numeric ,errors="coerce")
    dataconv = dataconv.drop(['zone','time'],axis=1)
    dataconv['zone'] = data['zone']
    dataconv['time'] = data['time']
    data = dataconv
    print(data['zone'])
    return(data)

# %%
data = convert_to_number(data)
print (data.dtypes)
# Out:
# 0         Nationale
# 1         Nationale
# 2         Nationale
# 3         Nationale
# 4         Nationale
#             ...
# 103877    Nationale
# 103878      Urbaine
# 103879      Urbaine
# 103880      Urbaine
# 103881      Urbaine
# Name: zone, Length: 103882, dtype: object
# CIN                        Int64
# altitude                 float64
# longitude                float64
# SPEED                    float64
# ENGINE_RPM               float64
# ENGINE_LOAD              float64
# AmbientAirTemp           float64
# ThrottlePos              float64
# valX                     float64
# valY                     float64
# valZ                     float64
# zone                      object
# time              datetime64[ns]
# dtype: object

# %% [markdown]
# ### Drop Nan values from Accelerometer

# %%
try:
    data = data.dropna(subset = ['valX', 'valY', 'valZ']) # if connected to distant database
except:
    data=data.dropna(subset = ['X', 'Y', 'Z'])# if connected tolocal database
data = data.reset_index(drop=True)

# %%
data.head(3)
# Out:
#        CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0  6023226  34.729739  10.655240    NaN         NaN          NaN
# 1  6023226  34.729750  10.655937    NaN         NaN          NaN
# 2  6023226  34.729785  10.656346   43.0      2112.0         72.2
#
#    AmbientAirTemp  ThrottlePos      valX      valY      valZ     zone  \
# 0             NaN          NaN  1.610234  8.581922  5.403137  Urbaine
# 1             NaN          NaN  2.545130  3.656662  8.467283  Urbaine
# 2            42.0         29.0  0.083398  7.703288  5.959764  Urbaine
#
#                  time
# 0 2020-07-22 17:12:12
# 1 2020-07-22 17:12:16
# 2 2020-07-22 17:12:20

# %%
data.shape
# Out:
# (100383, 13)

# %% [markdown]
# ### Create a function that transforms the accelerometer values to angle of rotation

# %% [markdown]
# ### Create angle rotation column

# %%
import math
angle_list,angle1, angle2, diff = [],0,0,0
for i in range (len(data)):
    if(i < len(data)-2): 
        angle1 = float(getBearing( float(data['altitude'].iloc[i]) , float(data['latitude'].iloc[i+1]), float(data['longitude'].iloc[i]),  float(data['longitude'].iloc[i+1])))
        angle2 = float(getBearing( float(data['alttitude'].iloc[i+1]),float(data['latitude'].iloc[i+2]), float(data['longitude'].iloc[i+1]),float(data['longitude'].iloc[i+2])))
        diff = float( max(angle1, angle2) - min(angle1, angle2))
        if (diff > 180):
            diff = 360 - diff
        angle_list.append(float(diff))
angle_list.extend([None for i in range (len(data)-len(angle_list))])
data['Angle_Rot']= np.array(angle_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-8be106061482> in <module>
#       3 for i in range (len(data)):
#       4     if(i < len(data)-2):
# ----> 5         angle1 = float(getBearing( float(data['altitude'].iloc[i]) , float(data['latitude'].iloc[i+1]), float(data['longitude'].iloc[i]),  float(data['longitude'].iloc[i+1])))
#       6         angle2 = float(getBearing( float(data['alttitude'].iloc[i+1]),float(data['latitude'].iloc[i+2]), float(data['longitude'].iloc[i+1]),float(data['longitude'].iloc[i+2])))
#       7         diff = float( max(angle1, angle2) - min(angle1, angle2))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'latitude'

# %%
xacc = data['X'] / 9.8 #- data['valX'].mean()
yacc = data['Y'] /9.8  #- data['valY'].mean()
zacc = data['Z'] / 9.8 #- data['valZ'].mean()
xacc2 = (xacc*xacc)
yacc2 = (yacc*yacc)
zacc2 = (zacc*zacc)
acc_angX = np.arctan(xacc /np.sqrt(yacc2+zacc2)) *57.32 #(180 / pi)
acc_angY = np.arctan(yacc /np.sqrt(xacc2+zacc2))*57.32 # (180 / pi)
acc_angZ = np.arctan(zacc /np.sqrt(xacc2+yacc2)) *57.32 # (180 / pi)
data['acc_angX'] = acc_angX
data['acc_angY'] = acc_angY
data['acc_angZ'] = acc_angZ
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'X'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-38f296b65a57> in <module>
# ----> 1 xacc = data['X'] / 9.8 #- data['valX'].mean()
#       2 yacc = data['Y'] /9.8  #- data['valY'].mean()
#       3 zacc = data['Z'] / 9.8 #- data['valZ'].mean()
#       4 xacc2 = (xacc*xacc)
#       5 yacc2 = (yacc*yacc)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'X'

# %%
data['Angle_Rot']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Angle_Rot'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-12ad51bc4c3f> in <module>
# ----> 1 data['Angle_Rot']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Angle_Rot'

# %% [markdown]
# ### extracting columns that have missing values

# %%
data.count()
# Out:
# CIN               100383
# altitude          100383
# longitude         100383
# SPEED              91673
# ENGINE_RPM         91662
# ENGINE_LOAD        91398
# AmbientAirTemp     91599
# ThrottlePos        91389
# valX              100383
# valY              100383
# valZ              100383
# zone              100383
# time              100383
# dtype: int64

# %%
missing_values_list = []
for i in range (len(data.columns)):
    if data.count()[i] != data['CIN'].count():
        missing_values_list.append(data.count().index[i])
data_missing_v = data[missing_values_list]

# %%
data_missing_v.count()
# Out:
# SPEED             91673
# ENGINE_RPM        91662
# ENGINE_LOAD       91398
# AmbientAirTemp    91599
# ThrottlePos       91389
# dtype: int64

# %%
data_missing_v
# Out:
#         SPEED  ENGINE_RPM  ENGINE_LOAD  AmbientAirTemp  ThrottlePos
# 0         NaN         NaN          NaN             NaN          NaN
# 1         NaN         NaN          NaN             NaN          NaN
# 2        43.0      2112.0         72.2            42.0         29.0
# 3        52.0      2559.0         76.9            42.0         30.6
# 4        61.0      2974.0         78.0            42.0         34.9
# ...       ...         ...          ...             ...          ...
# 100378   97.0      2732.0         63.5            32.0         28.2
# 100379    NaN         NaN          NaN             NaN          NaN
# 100380    NaN         NaN          NaN             NaN          NaN
# 100381    NaN         NaN          NaN             NaN          NaN
# 100382    NaN         NaN          NaN             NaN          NaN
#
# [100383 rows x 5 columns]

# %% [markdown]
# ### interpolate on the data with the missing values

# %%
def completing_missing_data(data):
    try:
        data_missing_v= data_missing_v.interpolate(method="cubic",limit=3)
    except:
        data['Speed'] = data['Speed'].astype('float')
        data_missing_v = data[missing_values_list]
        data_missing_v= data_missing_v.interpolate(method="cubic",limit=3)
    return (data_missing_v)

# %%
data_missing_v=completing_missing_data(data_missing_v)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-15-61f9cfbee058> in completing_missing_data(data)
#       2     try:
# ----> 3         data_missing_v= data_missing_v.interpolate(method="cubic",limit=3)
#       4     except:
#
# UnboundLocalError: local variable 'data_missing_v' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Speed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-7fd7d3bfa26d> in <module>
# ----> 1 data_missing_v=completing_missing_data(data_missing_v)
#
# <ipython-input-15-61f9cfbee058> in completing_missing_data(data)
#       3         data_missing_v= data_missing_v.interpolate(method="cubic",limit=3)
#       4     except:
# ----> 5         data['Speed'] = data['Speed'].astype('float')
#       6         data_missing_v = data[missing_values_list]
#       7         data_missing_v= data_missing_v.interpolate(method="cubic",limit=3)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Speed'

# %%
data_missing_v.count()
# Out:
# SPEED             91673
# ENGINE_RPM        91662
# ENGINE_LOAD       91398
# AmbientAirTemp    91599
# ThrottlePos       91389
# dtype: int64

# %%
data[missing_values_list] = data_missing_v
data.count()
# Out:
# CIN               100383
# altitude          100383
# longitude         100383
# SPEED              91673
# ENGINE_RPM         91662
# ENGINE_LOAD        91398
# AmbientAirTemp     91599
# ThrottlePos        91389
# valX              100383
# valY              100383
# valZ              100383
# zone              100383
# time              100383
# dtype: int64

# %% [markdown]
# ### remove any remaining missing data values

# %%
data = removing_incomplete_raws(data)

# %%
data.isnull().values.any() #checking for any null value in the data
# Out:
# False

# %%
data
# Out:
#            CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0      6023226  34.729785  10.656346   43.0      2112.0         72.2
# 1      6023226  34.729863  10.656757   52.0      2559.0         76.9
# 2      6023226  34.730034  10.657389   61.0      2974.0         78.0
# 3      6023226  34.730220  10.658135   65.0      3173.0         36.5
# 4      6023226  34.730323  10.658877   62.0      1443.0          0.0
# ...        ...        ...        ...    ...         ...          ...
# 91384  6023226  34.832037  10.727349   67.0      3265.0         78.4
# 91385  6023226  34.832240  10.727721   81.0      2578.0         85.9
# 91386  6023226  34.832704  10.728706   89.0       989.0         66.3
# 91387  6023226  34.834773  10.731364   90.0      2528.0         65.1
# 91388  6023226  34.834915  10.731546   97.0      2732.0         63.5
#
#        AmbientAirTemp  ThrottlePos      valX      valY      valZ       zone  \
# 0                42.0         29.0  0.083398  7.703288  5.959764    Urbaine
# 1                42.0         30.6  2.218036  9.894187  2.721148    Urbaine
# 2                42.0         34.9  0.567006  8.561572  4.537072    Urbaine
# 3                41.0         25.5 -0.047080  8.618731  4.569990    Urbaine
# 4                41.0         15.3  5.573964  8.053125  4.679521    Urbaine
# ...               ...          ...       ...       ...       ...        ...
# 91384            33.0         31.8 -0.204000  9.129000  3.712000  Nationale
# 91385            33.0         39.6 -0.584000  9.242000  3.638000  Nationale
# 91386            32.0         27.5 -0.534000  9.108000  4.725000  Nationale
# 91387            32.0         27.5 -0.172000  8.940000  3.926000  Nationale
# 91388            32.0         28.2 -0.578000  8.942000  4.038000  Nationale
#
#                      time
# 0     2020-07-22 17:12:20
# 1     2020-07-22 17:12:24
# 2     2020-07-22 17:12:28
# 3     2020-07-22 17:12:32
# 4     2020-07-22 17:12:36
# ...                   ...
# 91384 2021-04-30 10:18:48
# 91385 2021-04-30 10:18:50
# 91386 2021-04-30 10:18:55
# 91387 2021-04-30 10:19:08
# 91388 2021-04-30 10:19:09
#
# [91389 rows x 13 columns]

# %%
data['CIN'] = data['CIN'].astype('float')

# %% [markdown]
# ### creating the route location column

# %%
target_conditions  = [ (data['CIN'] == 2),  (data['CIN'] == 20), (data['CIN'] == 10000002), (data['CIN'] == 2020202),(data['CIN'] == 3) , (data['CIN'] == 4),(data['CIN'] == 1), (data['CIN'] == 10), (data['CIN'] == 1010101),(data['CIN'] == 10000001), (data['CIN'] == 11067773)]
target_choices     = ['normal', 'normal', 'normal', 'normal','agressif','dangerous','timid','timid','timid','timid','timid']
data["TargetValue"] = np.select(target_conditions, target_choices, default='not specified')
data['CIN'] = data['CIN'].astype('int')

# %%
data['TargetValue'] = data['TargetValue'].astype('category')
data['zone'] = data['zone'].astype('category')

# %%
print(data['zone'].unique())
print(data['TargetValue'].unique())
# Out:
# ['Urbaine', 'Nationale', 'Autoroute']
# Categories (3, object): ['Urbaine', 'Nationale', 'Autoroute']
# ['not specified', 'timid', 'normal', 'agressif', 'dangerous']
# Categories (5, object): ['not specified', 'timid', 'normal', 'agressif', 'dangerous']

# %% [markdown]
# ### Rearange columns by putting time last

# %%
data = data.reindex(columns=(list([a for a in data.columns if a != 'time'])+ ['time']  ))#reorder columns by putting time last

# %%
data
# Out:
#            CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0      6023226  34.729785  10.656346   43.0      2112.0         72.2
# 1      6023226  34.729863  10.656757   52.0      2559.0         76.9
# 2      6023226  34.730034  10.657389   61.0      2974.0         78.0
# 3      6023226  34.730220  10.658135   65.0      3173.0         36.5
# 4      6023226  34.730323  10.658877   62.0      1443.0          0.0
# ...        ...        ...        ...    ...         ...          ...
# 91384  6023226  34.832037  10.727349   67.0      3265.0         78.4
# 91385  6023226  34.832240  10.727721   81.0      2578.0         85.9
# 91386  6023226  34.832704  10.728706   89.0       989.0         66.3
# 91387  6023226  34.834773  10.731364   90.0      2528.0         65.1
# 91388  6023226  34.834915  10.731546   97.0      2732.0         63.5
#
#        AmbientAirTemp  ThrottlePos      valX      valY      valZ       zone  \
# 0                42.0         29.0  0.083398  7.703288  5.959764    Urbaine
# 1                42.0         30.6  2.218036  9.894187  2.721148    Urbaine
# 2                42.0         34.9  0.567006  8.561572  4.537072    Urbaine
# 3                41.0         25.5 -0.047080  8.618731  4.569990    Urbaine
# 4                41.0         15.3  5.573964  8.053125  4.679521    Urbaine
# ...               ...          ...       ...       ...       ...        ...
# 91384            33.0         31.8 -0.204000  9.129000  3.712000  Nationale
# 91385            33.0         39.6 -0.584000  9.242000  3.638000  Nationale
# 91386            32.0         27.5 -0.534000  9.108000  4.725000  Nationale
# 91387            32.0         27.5 -0.172000  8.940000  3.926000  Nationale
# 91388            32.0         28.2 -0.578000  8.942000  4.038000  Nationale
#
#          TargetValue                time
# 0      not specified 2020-07-22 17:12:20
# 1      not specified 2020-07-22 17:12:24
# 2      not specified 2020-07-22 17:12:28
# 3      not specified 2020-07-22 17:12:32
# 4      not specified 2020-07-22 17:12:36
# ...              ...                 ...
# 91384  not specified 2021-04-30 10:18:48
# 91385  not specified 2021-04-30 10:18:50
# 91386  not specified 2021-04-30 10:18:55
# 91387  not specified 2021-04-30 10:19:08
# 91388  not specified 2021-04-30 10:19:09
#
# [91389 rows x 14 columns]

# %% [markdown]
# ### saving the shortcut for preprocessed data

# %%
df = data

# %%
#data.to_csv(r'fetched_serveur_data_preprocessed.csv', index=False)
#data.to_csv(r'local_database_preprocessed.csv', index=False)

# %%
df
# Out:
#            CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0      6023226  34.729785  10.656346   43.0      2112.0         72.2
# 1      6023226  34.729863  10.656757   52.0      2559.0         76.9
# 2      6023226  34.730034  10.657389   61.0      2974.0         78.0
# 3      6023226  34.730220  10.658135   65.0      3173.0         36.5
# 4      6023226  34.730323  10.658877   62.0      1443.0          0.0
# ...        ...        ...        ...    ...         ...          ...
# 91384  6023226  34.832037  10.727349   67.0      3265.0         78.4
# 91385  6023226  34.832240  10.727721   81.0      2578.0         85.9
# 91386  6023226  34.832704  10.728706   89.0       989.0         66.3
# 91387  6023226  34.834773  10.731364   90.0      2528.0         65.1
# 91388  6023226  34.834915  10.731546   97.0      2732.0         63.5
#
#        AmbientAirTemp  ThrottlePos      valX      valY      valZ       zone  \
# 0                42.0         29.0  0.083398  7.703288  5.959764    Urbaine
# 1                42.0         30.6  2.218036  9.894187  2.721148    Urbaine
# 2                42.0         34.9  0.567006  8.561572  4.537072    Urbaine
# 3                41.0         25.5 -0.047080  8.618731  4.569990    Urbaine
# 4                41.0         15.3  5.573964  8.053125  4.679521    Urbaine
# ...               ...          ...       ...       ...       ...        ...
# 91384            33.0         31.8 -0.204000  9.129000  3.712000  Nationale
# 91385            33.0         39.6 -0.584000  9.242000  3.638000  Nationale
# 91386            32.0         27.5 -0.534000  9.108000  4.725000  Nationale
# 91387            32.0         27.5 -0.172000  8.940000  3.926000  Nationale
# 91388            32.0         28.2 -0.578000  8.942000  4.038000  Nationale
#
#          TargetValue                time
# 0      not specified 2020-07-22 17:12:20
# 1      not specified 2020-07-22 17:12:24
# 2      not specified 2020-07-22 17:12:28
# 3      not specified 2020-07-22 17:12:32
# 4      not specified 2020-07-22 17:12:36
# ...              ...                 ...
# 91384  not specified 2021-04-30 10:18:48
# 91385  not specified 2021-04-30 10:18:50
# 91386  not specified 2021-04-30 10:18:55
# 91387  not specified 2021-04-30 10:19:08
# 91388  not specified 2021-04-30 10:19:09
#
# [91389 rows x 14 columns]

# %%
def Time_conv(time): # time est sous le format "jour/mois/année h:min"
    l=str(time).split(' ')  # time extraction
    time =l[-1].split(':') # extraire h et min
    time_converted=int(time[0])*3600+int(time[1])*60 + int(time[2]) # convertir en  sec
    #print(time[0], time[1], time[2])
    
    return(time_converted)

def time_conv_list(trip):
    l=list()
    for temps in trip['time']:
        #print("time conv", Time_conv(temps))
        l.append(Time_conv(temps)) # enregistrer les temps convertis dans une liste
    return(l)

def trip_segmentation(trip):
    l=list()
    for index in trip['time']:
        l.append(Time_conv(index)) # enregistrer les temps convertis dans une liste
    time_limits=list()
    time_limits.append(0)
    for index in range(len(l)-1): # parcourir la liste pour segmenter les trips
       
        if ((l[index+1]-l[index])>20): # si la difference en time entre deux valeurs successives depasse une min on sépare les trips
            time_limits.append(index)
            time_limits.append(index+1)# liste des indexs des différents trips
    time_limits.append(len(trip)-1)
    print("time trip limits : \n", time_limits)
    new_time_limits=list()
    w=(len(time_limits))
    for i in range(0,(w-1),2):

        if (time_limits[i+1]-time_limits[i] < 10): # si le trip contient mois que 10 valeurs on l élimine
            continue
        new_time_limits.append(time_limits[i])
        new_time_limits.append(time_limits[i+1])
    return(new_time_limits)

# %%
print(data['time'][1])
print(Time_conv(data['time'][1]))
# Out:
# 2020-07-22 17:12:24
# 61944

# %%
Time_conv(data['time'][1])
# Out:
# 61944

# %%
l=time_conv_list(data)
l
#print("liste des temps convertis : \n", l)
# Out:
# [61940,
#  61944,
#  61948,
#  61952,
#  61956,
#  61960,
#  61964,
#  61968,
#  61972,
#  61976,
#  61980,
#  61984,
#  61988,
#  61992,
#  61996,
#  62000,
#  62004,
#  62008,
#  62012,
#  62016,
#  62020,
#  62024,
#  62028,
#  62032,
#  62036,
#  62040,
#  62044,
#  62048,
#  62052,
#  62056,
#  62060,
#  62064,
#  62068,
#  62072,
#  62076,
#  62080,
#  62084,
#  62088,
#  62092,
#  62096,
#  62100,
#  62104,
#  62108,
#  62112,
#  62116,
#  62120,
#  62124,
#  62128,
#  62131,
#  62134,
#  62138,
#  62142,
#  62146,
#  62149,
#  62153,
#  62157,
#  62161,
#  62165,
#  62169,
#  62173,
#  62177,
#  62181,
#  62185,
#  62189,
#  62193,
#  62197,
#  62201,
#  62205,
#  62209,
#  62213,
#  62217,
#  62221,
#  62225,
#  62229,
#  62233,
#  62237,
#  62241,
#  62245,
#  62248,
#  62252,
#  62256,
#  62260,
#  62264,
#  62268,
#  62272,
#  62276,
#  62280,
#  62284,
#  62288,
#  62292,
#  62296,
#  62300,
#  62304,
#  70066,
#  70070,
#  70074,
#  70078,
#  70082,
#  70086,
#  70090,
#  70094,
#  70098,
#  70102,
#  70106,
#  70110,
#  70114,
#  70118,
#  70122,
#  70126,
#  70130,
#  70134,
#  70138,
#  70142,
#  70146,
#  70150,
#  70154,
#  70188,
#  70211,
#  70215,
#  70219,
#  70223,
#  70227,
#  70231,
#  70234,
#  70238,
#  70242,
#  70246,
#  70250,
#  70254,
#  70258,
#  70262,
#  70266,
#  70270,
#  70274,
#  70278,
#  70281,
#  70302,
#  70306,
#  70309,
#  70313,
#  70317,
#  70321,
#  70325,
#  70329,
#  70333,
#  70336,
#  70340,
#  70343,
#  70347,
#  70352,
#  70356,
#  70360,
#  70364,
#  70368,
#  70372,
#  70376,
#  70380,
#  70384,
#  70388,
#  70392,
#  70395,
#  70399,
#  71478,
#  71482,
#  71486,
#  71489,
#  71493,
#  71497,
#  71501,
#  71505,
#  71509,
#  71513,
#  71517,
#  71521,
#  71525,
#  71528,
#  71531,
#  71535,
#  71538,
#  71542,
#  71546,
#  71550,
#  71553,
#  71557,
#  71563,
#  71568,
#  71572,
#  71576,
#  71590,
#  71597,
#  71601,
#  71605,
#  71625,
#  71632,
#  71638,
#  71642,
#  71669,
#  71678,
#  71687,
#  71692,
#  71709,
#  71716,
#  71720,
#  71724,
#  71728,
#  71732,
#  71736,
#  71740,
#  71744,
#  71758,
#  71765,
#  71769,
#  71773,
#  71777,
#  71781,
#  71785,
#  71789,
#  71793,
#  71797,
#  71801,
#  71805,
#  71809,
#  71813,
#  71817,
#  71821,
#  71825,
#  74815,
#  74819,
#  74823,
#  74827,
#  74831,
#  74853,
#  74863,
#  74872,
#  74877,
#  74886,
#  74894,
#  74899,
#  74908,
#  74913,
#  74922,
#  74933,
#  74937,
#  74941,
#  74945,
#  74949,
#  74953,
#  ...]

# %%
df['CIN'].unique()
# Out:
# array([ 6023226,  1010101,        2,        3,        4,        1,
#        10000001, 10000002,       10,       20,  1234567, 11067773,
#         5344439])

# %%
group = df.groupby('CIN')

normal_df = group.get_group(2)
agressif_df = group.get_group(3)
dangerous_df = group.get_group(4)
timid_df = group.get_group(1)
timid_df = timid_df.reset_index(drop=True)
normal_df =normal_df.reset_index(drop=True)
agressif_df = agressif_df.reset_index(drop=True)
dangerous_df =dangerous_df.reset_index(drop=True)

# %%
#segs=trip_segmentation(data)
segs_normal=trip_segmentation(normal_df)
segs_agressif=trip_segmentation(agressif_df)
segs_dangerous=trip_segmentation(dangerous_df)
segs_timid=trip_segmentation(timid_df)
# Out:
# time trip limits :
#  [0, 145, 146, 191, 192, 197, 198, 332, 333, 623, 624, 724, 725, 843, 844, 884, 885, 939, 940, 1026, 1027, 1076, 1077, 1315, 1316, 1584, 1585, 1590, 1591, 1871, 1872, 1910, 1911, 1942, 1943, 1966, 1967, 1994, 1995, 2263, 2264, 2752, 2753, 2753, 2754, 3005, 3006, 3265, 3266, 3712, 3713, 3782, 3783, 3802, 3803, 3808, 3809, 3886, 3887, 3945, 3946, 4083, 4084, 4386, 4387, 4464, 4465, 4731, 4732, 4735, 4736, 5059, 5060, 5238, 5239, 5332, 5333, 5623, 5624, 5689, 5690, 5836, 5837, 5858, 5859, 6153, 6154, 6561, 6562, 6598, 6599, 7549, 7550, 7552, 7553, 7615, 7616, 7976, 7977, 8299, 8300, 8724, 8725, 8810, 8811, 8818, 8819, 9035, 9036, 9041, 9042, 9323, 9324, 9682, 9683, 10240, 10241, 10512, 10513, 10513]
# time trip limits :
#  [0, 151, 152, 167, 168, 286, 287, 527, 528, 666, 667, 680, 681, 771, 772, 865, 866, 951, 952, 979, 980, 992, 993, 1072, 1073, 1194, 1195, 1223, 1224, 1288, 1289, 1317, 1318, 1376, 1377, 1451, 1452, 1548, 1549, 1683, 1684, 1772, 1773, 1898, 1899, 1953, 1954, 2180, 2181, 2222, 2223, 2295, 2296, 2299, 2300, 2364, 2365, 2484, 2485, 2639, 2640, 2860, 2861, 2958, 2959, 3107, 3108, 3128, 3129, 3267, 3268, 3588, 3589, 3845, 3846, 3986, 3987, 3989, 3990, 4074, 4075, 4225, 4226, 4253, 4254, 4624, 4625, 4753, 4754, 4756, 4757, 5021, 5022, 5066, 5067, 5200, 5201, 5394, 5395, 5576, 5577, 5728, 5729, 6206, 6207, 6360, 6361, 6705, 6706, 6978, 6979, 7008, 7009, 7081, 7082, 7087, 7088, 7097, 7098, 7170, 7171, 7172, 7173, 7583, 7584, 7598, 7599, 7601, 7602, 7852, 7853, 7855, 7856, 7871, 7872, 7885, 7886, 7886, 7887, 7888, 7889, 7889, 7890, 7890, 7891, 7891, 7892, 7892, 7893, 7893, 7894, 7894, 7895, 7895, 7896, 7896, 7897, 7897, 7898, 7898, 7899, 7899, 7900, 7900, 7901, 7901, 7902, 7902, 7903, 7903, 7904, 7904, 7905, 7905, 7906, 7907, 7908, 7917, 7918, 8139, 8140, 8553, 8554, 8856]
# time trip limits :
#  [0, 9, 10, 11, 12, 14, 15, 17, 18, 125, 126, 169, 170, 364, 365, 472, 473, 623, 624, 674, 675, 757, 758, 1074, 1075, 1167, 1168, 1434, 1435, 1713, 1714, 1730, 1731, 1762, 1763, 1917, 1918, 1921, 1922, 1939, 1940, 2012, 2013, 2237, 2238, 2263, 2264, 2334, 2335, 2395, 2396, 2724, 2725, 2803, 2804, 2817, 2818, 2826, 2827, 2827, 2828, 2828, 2829, 2834, 2835, 2852, 2853, 3001, 3002, 3312, 3313, 3313, 3314, 3314, 3315, 3315, 3316, 3316, 3317, 3317, 3318, 3318, 3319, 3319, 3320, 3321]
# time trip limits :
#  [0, 9, 10, 124, 125, 131, 132, 210, 211, 217, 218, 322, 323, 407, 408, 596, 597, 809, 810, 831, 832, 846, 847, 916, 917, 1168, 1169, 1571, 1572, 1663, 1664, 1664, 1665, 1665, 1666, 2116, 2117, 2249, 2250, 2327, 2328, 2328, 2329, 2572, 2573, 2784, 2785, 2862, 2863, 2886, 2887, 2912, 2913, 2976, 2977, 2977, 2978, 3183, 3184, 3482, 3483, 3517]

# %%
# eliminer les fausses trips de la liste des trips initiale
def del_unsignicant_trip(data, segs):
    trip_cleaned=data.copy(deep='False')
    #print(len(trip_cleaned))
    x =tuple()
    segments=list()
    for i in range(0,len(segs)-1,2):
        x=(segs[i], segs[i+1])
        segments.append(x) 
    print(segments)

    for i in range(len(segments)-1):
        if segments[i+1][0] - segments[i][1]==1:
            print("dropped segs", segments[i], segments[i+1])
            continue
        print(range(segments[i][1]+1, segments[i+1][0] ))
        print(trip_cleaned)
        trip_cleaned = trip_cleaned.drop(index=range(segments[i][1]+1, segments[i+1][0] ), inplace=False)
    trip_cleaned = trip_cleaned.drop(index=range(len(trip_cleaned)-(len(trip_cleaned))%10-1, len(trip_cleaned)-1 ), inplace=False)
        
    return(trip_cleaned)

# %%
normal_trip_cleaned=del_unsignicant_trip(normal_df, segs_normal)
#print(normal_trip_cleaned)
agressif_trip_cleaned=del_unsignicant_trip(agressif_df, segs_agressif)
dangerous_trip_cleaned=del_unsignicant_trip(dangerous_df, segs_dangerous)
timid_trip_cleaned=del_unsignicant_trip(timid_df, segs_timid)
# Out:
# [(0, 145), (146, 191), (198, 332), (333, 623), (624, 724), (725, 843), (844, 884), (885, 939), (940, 1026), (1027, 1076), (1077, 1315), (1316, 1584), (1591, 1871), (1872, 1910), (1911, 1942), (1943, 1966), (1967, 1994), (1995, 2263), (2264, 2752), (2754, 3005), (3006, 3265), (3266, 3712), (3713, 3782), (3783, 3802), (3809, 3886), (3887, 3945), (3946, 4083), (4084, 4386), (4387, 4464), (4465, 4731), (4736, 5059), (5060, 5238), (5239, 5332), (5333, 5623), (5624, 5689), (5690, 5836), (5837, 5858), (5859, 6153), (6154, 6561), (6562, 6598), (6599, 7549), (7553, 7615), (7616, 7976), (7977, 8299), (8300, 8724), (8725, 8810), (8819, 9035), (9042, 9323), (9324, 9682), (9683, 10240), (10241, 10512)]
# dropped segs (0, 145) (146, 191)
# range(192, 198)
#        CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0        2  34.835627  10.754101    0.0         0.0         88.6
# 1        2  34.835634  10.754102    0.0       880.0         27.8
# 2        2  34.835640  10.754083    3.0      1663.0         27.5
# 3        2  34.835648  10.754064    3.0      1170.0         24.7
# 4        2  34.835692  10.754052    9.0      1219.0         32.9
# ...    ...        ...        ...    ...         ...          ...
# 10509    2  34.704697  10.720648   53.0      1880.0         22.4
# 10510    2  34.704191  10.720385   55.0      1924.0         30.2
# 10511    2  34.703691  10.720128   54.0      1875.0          1.2
# 10512    2  34.727592  10.715250   42.0      2044.0         25.5
# 10513    2  34.703206  10.719881   54.0      1889.0         21.6
#
#        AmbientAirTemp  ThrottlePos   valX   valY   valZ     zone TargetValue  \
# 0                49.0         11.4 -0.017  3.564  8.619  Urbaine      normal
# 1                49.0         16.5  0.113  3.404  9.141  Urbaine      normal
# 2                49.0         18.0  0.104  3.714  9.572  Urbaine      normal
# 3                49.0         16.9  0.076  4.046  9.129  Urbaine      normal
# 4                49.0         19.2 -1.060  3.367  9.312  Urbaine      normal
# ...               ...          ...    ...    ...    ...      ...         ...
# 10509            40.0         18.4  0.374  8.455  3.637  Urbaine      normal
# 10510            40.0         19.2  0.278  9.071  3.769  Urbaine      normal
# 10511            40.0         15.7  0.707  8.156  3.801  Urbaine      normal
# 10512            35.0         19.2  0.018  9.153  3.900  Urbaine      normal
# 10513            40.0         17.3 -0.007  9.266  3.997  Urbaine      normal
#
#                      time
# 0     2020-08-24 10:04:59
# 1     2020-08-24 10:05:03
# 2     2020-08-24 10:05:07
# 3     2020-08-24 10:05:11
# 4     2020-08-24 10:05:15
# ...                   ...
# 10509 2021-04-18 16:37:22
# 10510 2021-04-18 16:37:26
# 10511 2021-04-18 16:37:30
# 10512 2021-04-18 16:26:03
# 10513 2021-04-18 16:37:34
#
# [10514 rows x 14 columns]
# dropped segs (198, 332) (333, 623)
# dropped segs (333, 623) (624, 724)
# dropped segs (624, 724) (725, 843)
# dropped segs (725, 843) (844, 884)
# dropped segs (844, 884) (885, 939)
# dropped segs (885, 939) (940, 1026)
# dropped segs (940, 1026) (1027, 1076)
# dropped segs (1027, 1076) (1077, 1315)
# dropped segs (1077, 1315) (1316, 1584)
# range(1585, 1591)
#        CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0        2  34.835627  10.754101    0.0         0.0         88.6
# 1        2  34.835634  10.754102    0.0       880.0         27.8
# 2        2  34.835640  10.754083    3.0      1663.0         27.5
# 3        2  34.835648  10.754064    3.0      1170.0         24.7
# 4        2  34.835692  10.754052    9.0      1219.0         32.9
# ...    ...        ...        ...    ...         ...          ...
# 10509    2  34.704697  10.720648   53.0      1880.0         22.4
# 10510    2  34.704191  10.720385   55.0      1924.0         30.2
# 10511    2  34.703691  10.720128   54.0      1875.0          1.2
# 10512    2  34.727592  10.715250   42.0      2044.0         25.5
# 10513    2  34.703206  10.719881   54.0      1889.0         21.6
#
#        AmbientAirTemp  ThrottlePos   valX   valY   valZ     zone TargetValue  \
# 0                49.0         11.4 -0.017  3.564  8.619  Urbaine      normal
# 1                49.0         16.5  0.113  3.404  9.141  Urbaine      normal
# 2                49.0         18.0  0.104  3.714  9.572  Urbaine      normal
# 3                49.0         16.9  0.076  4.046  9.129  Urbaine      normal
# 4                49.0         19.2 -1.060  3.367  9.312  Urbaine      normal
# ...               ...          ...    ...    ...    ...      ...         ...
# 10509            40.0         18.4  0.374  8.455  3.637  Urbaine      normal
# 10510            40.0         19.2  0.278  9.071  3.769  Urbaine      normal
# 10511            40.0         15.7  0.707  8.156  3.801  Urbaine      normal
# 10512            35.0         19.2  0.018  9.153  3.900  Urbaine      normal
# 10513            40.0         17.3 -0.007  9.266  3.997  Urbaine      normal
#
#                      time
# 0     2020-08-24 10:04:59
# 1     2020-08-24 10:05:03
# 2     2020-08-24 10:05:07
# 3     2020-08-24 10:05:11
# 4     2020-08-24 10:05:15
# ...                   ...
# 10509 2021-04-18 16:37:22
# 10510 2021-04-18 16:37:26
# 10511 2021-04-18 16:37:30
# 10512 2021-04-18 16:26:03
# 10513 2021-04-18 16:37:34
#
# [10508 rows x 14 columns]
# dropped segs (1591, 1871) (1872, 1910)
# dropped segs (1872, 1910) (1911, 1942)
# dropped segs (1911, 1942) (1943, 1966)
# dropped segs (1943, 1966) (1967, 1994)
# dropped segs (1967, 1994) (1995, 2263)
# dropped segs (1995, 2263) (2264, 2752)
# range(2753, 2754)
#        CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0        2  34.835627  10.754101    0.0         0.0         88.6
# 1        2  34.835634  10.754102    0.0       880.0         27.8
# 2        2  34.835640  10.754083    3.0      1663.0         27.5
# 3        2  34.835648  10.754064    3.0      1170.0         24.7
# 4        2  34.835692  10.754052    9.0      1219.0         32.9
# ...    ...        ...        ...    ...         ...          ...
# 10509    2  34.704697  10.720648   53.0      1880.0         22.4
# 10510    2  34.704191  10.720385   55.0      1924.0         30.2
# 10511    2  34.703691  10.720128   54.0      1875.0          1.2
# 10512    2  34.727592  10.715250   42.0      2044.0         25.5
# 10513    2  34.703206  10.719881   54.0      1889.0         21.6
#
#        AmbientAirTemp  ThrottlePos   valX   valY   valZ     zone TargetValue  \
# 0                49.0         11.4 -0.017  3.564  8.619  Urbaine      normal
# 1                49.0         16.5  0.113  3.404  9.141  Urbaine      normal
# 2                49.0         18.0  0.104  3.714  9.572  Urbaine      normal
# 3                49.0         16.9  0.076  4.046  9.129  Urbaine      normal
# 4                49.0         19.2 -1.060  3.367  9.312  Urbaine      normal
# ...               ...          ...    ...    ...    ...      ...         ...
# 10509            40.0         18.4  0.374  8.455  3.637  Urbaine      normal
# 10510            40.0         19.2  0.278  9.071  3.769  Urbaine      normal
# 10511            40.0         15.7  0.707  8.156  3.801  Urbaine      normal
# 10512            35.0         19.2  0.018  9.153  3.900  Urbaine      normal
# 10513            40.0         17.3 -0.007  9.266  3.997  Urbaine      normal
#
#                      time
# 0     2020-08-24 10:04:59
# 1     2020-08-24 10:05:03
# 2     2020-08-24 10:05:07
# 3     2020-08-24 10:05:11
# 4     2020-08-24 10:05:15
# ...                   ...
# 10509 2021-04-18 16:37:22
# 10510 2021-04-18 16:37:26
# 10511 2021-04-18 16:37:30
# 10512 2021-04-18 16:26:03
# 10513 2021-04-18 16:37:34
#
# [10502 rows x 14 columns]
# dropped segs (2754, 3005) (3006, 3265)
# dropped segs (3006, 3265) (3266, 3712)
# dropped segs (3266, 3712) (3713, 3782)
# dropped segs (3713, 3782) (3783, 3802)
# range(3803, 3809)
#        CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0        2  34.835627  10.754101    0.0         0.0         88.6
# 1        2  34.835634  10.754102    0.0       880.0         27.8
# 2        2  34.835640  10.754083    3.0      1663.0         27.5
# 3        2  34.835648  10.754064    3.0      1170.0         24.7
# 4        2  34.835692  10.754052    9.0      1219.0         32.9
# ...    ...        ...        ...    ...         ...          ...
# 10509    2  34.704697  10.720648   53.0      1880.0         22.4
# 10510    2  34.704191  10.720385   55.0      1924.0         30.2
# 10511    2  34.703691  10.720128   54.0      1875.0          1.2
# 10512    2  34.727592  10.715250   42.0      2044.0         25.5
# 10513    2  34.703206  10.719881   54.0      1889.0         21.6
#
#        AmbientAirTemp  ThrottlePos   valX   valY   valZ     zone TargetValue  \
# 0                49.0         11.4 -0.017  3.564  8.619  Urbaine      normal
# 1                49.0         16.5  0.113  3.404  9.141  Urbaine      normal
# 2                49.0         18.0  0.104  3.714  9.572  Urbaine      normal
# 3                49.0         16.9  0.076  4.046  9.129  Urbaine      normal
# 4                49.0         19.2 -1.060  3.367  9.312  Urbaine      normal
# ...               ...          ...    ...    ...    ...      ...         ...
# 10509            40.0         18.4  0.374  8.455  3.637  Urbaine      normal
# 10510            40.0         19.2  0.278  9.071  3.769  Urbaine      normal
# 10511            40.0         15.7  0.707  8.156  3.801  Urbaine      normal
# 10512            35.0         19.2  0.018  9.153  3.900  Urbaine      normal
# 10513            40.0         17.3 -0.007  9.266  3.997  Urbaine      normal
#
#                      time
# 0     2020-08-24 10:04:59
# 1     2020-08-24 10:05:03
# 2     2020-08-24 10:05:07
# 3     2020-08-24 10:05:11
# 4     2020-08-24 10:05:15
# ...                   ...
# 10509 2021-04-18 16:37:22
# 10510 2021-04-18 16:37:26
# 10511 2021-04-18 16:37:30
# 10512 2021-04-18 16:26:03
# 10513 2021-04-18 16:37:34
#
# [10501 rows x 14 columns]
# dropped segs (3809, 3886) (3887, 3945)
# dropped segs (3887, 3945) (3946, 4083)
# dropped segs (3946, 4083) (4084, 4386)
# dropped segs (4084, 4386) (4387, 4464)
# dropped segs (4387, 4464) (4465, 4731)
# range(4732, 4736)
#        CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0        2  34.835627  10.754101    0.0         0.0         88.6
# 1        2  34.835634  10.754102    0.0       880.0         27.8
# 2        2  34.835640  10.754083    3.0      1663.0         27.5
# 3        2  34.835648  10.754064    3.0      1170.0         24.7
# 4        2  34.835692  10.754052    9.0      1219.0         32.9
# ...    ...        ...        ...    ...         ...          ...
# 10509    2  34.704697  10.720648   53.0      1880.0         22.4
# 10510    2  34.704191  10.720385   55.0      1924.0         30.2
# 10511    2  34.703691  10.720128   54.0      1875.0          1.2
# 10512    2  34.727592  10.715250   42.0      2044.0         25.5
# 10513    2  34.703206  10.719881   54.0      1889.0         21.6
#
#        AmbientAirTemp  ThrottlePos   valX   valY   valZ     zone TargetValue  \
# 0                49.0         11.4 -0.017  3.564  8.619  Urbaine      normal
# 1                49.0         16.5  0.113  3.404  9.141  Urbaine      normal
# 2                49.0         18.0  0.104  3.714  9.572  Urbaine      normal
# 3                49.0         16.9  0.076  4.046  9.129  Urbaine      normal
# 4                49.0         19.2 -1.060  3.367  9.312  Urbaine      normal
# ...               ...          ...    ...    ...    ...      ...         ...
# 10509            40.0         18.4  0.374  8.455  3.637  Urbaine      normal
# 10510            40.0         19.2  0.278  9.071  3.769  Urbaine      normal
# 10511            40.0         15.7  0.707  8.156  3.801  Urbaine      normal
# 10512            35.0         19.2  0.018  9.153  3.900  Urbaine      normal
# 10513            40.0         17.3 -0.007  9.266  3.997  Urbaine      normal
#
#                      time
# 0     2020-08-24 10:04:59
# 1     2020-08-24 10:05:03
# 2     2020-08-24 10:05:07
# 3     2020-08-24 10:05:11
# 4     2020-08-24 10:05:15
# ...                   ...
# 10509 2021-04-18 16:37:22
# 10510 2021-04-18 16:37:26
# 10511 2021-04-18 16:37:30
# 10512 2021-04-18 16:26:03
# 10513 2021-04-18 16:37:34
#
# [10495 rows x 14 columns]
# dropped segs (4736, 5059) (5060, 5238)
# dropped segs (5060, 5238) (5239, 5332)
# dropped segs (5239, 5332) (5333, 5623)
# dropped segs (5333, 5623) (5624, 5689)
# dropped segs (5624, 5689) (5690, 5836)
# dropped segs (5690, 5836) (5837, 5858)
# dropped segs (5837, 5858) (5859, 6153)
# dropped segs (5859, 6153) (6154, 6561)
# dropped segs (6154, 6561) (6562, 6598)
# dropped segs (6562, 6598) (6599, 7549)
# range(7550, 7553)
#        CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0        2  34.835627  10.754101    0.0         0.0         88.6
# 1        2  34.835634  10.754102    0.0       880.0         27.8
# 2        2  34.835640  10.754083    3.0      1663.0         27.5
# 3        2  34.835648  10.754064    3.0      1170.0         24.7
# 4        2  34.835692  10.754052    9.0      1219.0         32.9
# ...    ...        ...        ...    ...         ...          ...
# 10509    2  34.704697  10.720648   53.0      1880.0         22.4
# 10510    2  34.704191  10.720385   55.0      1924.0         30.2
# 10511    2  34.703691  10.720128   54.0      1875.0          1.2
# 10512    2  34.727592  10.715250   42.0      2044.0         25.5
# 10513    2  34.703206  10.719881   54.0      1889.0         21.6
#
#        AmbientAirTemp  ThrottlePos   valX   valY   valZ     zone TargetValue  \
# 0                49.0         11.4 -0.017  3.564  8.619  Urbaine      normal
# 1                49.0         16.5  0.113  3.404  9.141  Urbaine      normal
# 2                49.0         18.0  0.104  3.714  9.572  Urbaine      normal
# 3                49.0         16.9  0.076  4.046  9.129  Urbaine      normal
# 4                49.0         19.2 -1.060  3.367  9.312  Urbaine      normal
# ...               ...          ...    ...    ...    ...      ...         ...
# 10509            40.0         18.4  0.374  8.455  3.637  Urbaine      normal
# 10510            40.0         19.2  0.278  9.071  3.769  Urbaine      normal
# 10511            40.0         15.7  0.707  8.156  3.801  Urbaine      normal
# 10512            35.0         19.2  0.018  9.153  3.900  Urbaine      normal
# 10513            40.0         17.3 -0.007  9.266  3.997  Urbaine      normal
#
#                      time
# 0     2020-08-24 10:04:59
# 1     2020-08-24 10:05:03
# 2     2020-08-24 10:05:07
# 3     2020-08-24 10:05:11
# 4     2020-08-24 10:05:15
# ...                   ...
# 10509 2021-04-18 16:37:22
# 10510 2021-04-18 16:37:26
# 10511 2021-04-18 16:37:30
# 10512 2021-04-18 16:26:03
# 10513 2021-04-18 16:37:34
#
# [10491 rows x 14 columns]
# dropped segs (7553, 7615) (7616, 7976)
# dropped segs (7616, 7976) (7977, 8299)
# dropped segs (7977, 8299) (8300, 8724)
# dropped segs (8300, 8724) (8725, 8810)
# range(8811, 8819)
#        CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0        2  34.835627  10.754101    0.0         0.0         88.6
# 1        2  34.835634  10.754102    0.0       880.0         27.8
# 2        2  34.835640  10.754083    3.0      1663.0         27.5
# 3        2  34.835648  10.754064    3.0      1170.0         24.7
# 4        2  34.835692  10.754052    9.0      1219.0         32.9
# ...    ...        ...        ...    ...         ...          ...
# 10509    2  34.704697  10.720648   53.0      1880.0         22.4
# 10510    2  34.704191  10.720385   55.0      1924.0         30.2
# 10511    2  34.703691  10.720128   54.0      1875.0          1.2
# 10512    2  34.727592  10.715250   42.0      2044.0         25.5
# 10513    2  34.703206  10.719881   54.0      1889.0         21.6
#
#        AmbientAirTemp  ThrottlePos   valX   valY   valZ     zone TargetValue  \
# 0                49.0         11.4 -0.017  3.564  8.619  Urbaine      normal
# 1                49.0         16.5  0.113  3.404  9.141  Urbaine      normal
# 2                49.0         18.0  0.104  3.714  9.572  Urbaine      normal
# 3                49.0         16.9  0.076  4.046  9.129  Urbaine      normal
# 4                49.0         19.2 -1.060  3.367  9.312  Urbaine      normal
# ...               ...          ...    ...    ...    ...      ...         ...
# 10509            40.0         18.4  0.374  8.455  3.637  Urbaine      normal
# 10510            40.0         19.2  0.278  9.071  3.769  Urbaine      normal
# 10511            40.0         15.7  0.707  8.156  3.801  Urbaine      normal
# 10512            35.0         19.2  0.018  9.153  3.900  Urbaine      normal
# 10513            40.0         17.3 -0.007  9.266  3.997  Urbaine      normal
#
#                      time
# 0     2020-08-24 10:04:59
# 1     2020-08-24 10:05:03
# 2     2020-08-24 10:05:07
# 3     2020-08-24 10:05:11
# 4     2020-08-24 10:05:15
# ...                   ...
# 10509 2021-04-18 16:37:22
# 10510 2021-04-18 16:37:26
# 10511 2021-04-18 16:37:30
# 10512 2021-04-18 16:26:03
# 10513 2021-04-18 16:37:34
#
# [10488 rows x 14 columns]
# range(9036, 9042)
#        CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0        2  34.835627  10.754101    0.0         0.0         88.6
# 1        2  34.835634  10.754102    0.0       880.0         27.8
# 2        2  34.835640  10.754083    3.0      1663.0         27.5
# 3        2  34.835648  10.754064    3.0      1170.0         24.7
# 4        2  34.835692  10.754052    9.0      1219.0         32.9
# ...    ...        ...        ...    ...         ...          ...
# 10509    2  34.704697  10.720648   53.0      1880.0         22.4
# 10510    2  34.704191  10.720385   55.0      1924.0         30.2
# 10511    2  34.703691  10.720128   54.0      1875.0          1.2
# 10512    2  34.727592  10.715250   42.0      2044.0         25.5
# 10513    2  34.703206  10.719881   54.0      1889.0         21.6
#
#        AmbientAirTemp  ThrottlePos   valX   valY   valZ     zone TargetValue  \
# 
# dropped segs (1318, 1376) (1377, 1451)
# dropped segs (1377, 1451) (1452, 1548)
# dropped segs (1452, 1548) (1549, 1683)
# dropped segs (1549, 1683) (1684, 1772)
# dropped segs (1684, 1772) (1773, 1898)
# dropped segs (1773, 1898) (1899, 1953)
# dropped segs (1899, 1953) (1954, 2180)
# dropped segs (1954, 2180) (2181, 2222)
# dropped segs (2181, 2222) (2223, 2295)
# range(2296, 2300)
#       CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0       3  34.836142  10.755176    4.0      2357.0         34.5
# 1       3  34.836004  10.755005   24.0      3515.0         72.9
# 2       3  34.835828  10.754746   40.0      3213.0         94.9
# 3       3  34.835532  10.754236   52.0      2559.0         96.1
# 4       3  34.835464  10.753682   44.0      2126.0          0.0
# ...   ...        ...        ...    ...         ...          ...
# 8852    3  34.577476  10.584655   14.0       841.0         13.7
# 8853    3  34.577374  10.584555   15.0      1138.0         25.1
# 8854    3  34.577224  10.584422   18.0      1438.0         30.2
# 8855    3  34.576934  10.584160   29.0      2316.0         14.9
# 8856    3  34.576751  10.583980   30.0      2356.0         23.5
#
#       AmbientAirTemp  ThrottlePos   valX   valY    valZ     zone TargetValue  \
# 0               49.0         22.0 -0.468  5.105   8.536  Urbaine    agressif
# 1               49.0         39.6 -0.371  4.347   8.874  Urbaine    agressif
# 2               49.0         88.2 -0.225  3.594   8.585  Urbaine    agressif
# 3               49.0         88.2  1.334  1.295  10.185  Urbaine    agressif
# 4               49.0         16.1  0.155  4.378   8.993  Urbaine    agressif
# ...              ...          ...    ...    ...     ...      ...         ...
# 8852            29.0         13.7  0.418  9.375   4.206  Urbaine    agressif
# 8853            29.0         16.9  0.401  9.227   3.037  Urbaine    agressif
# 8854            29.0         28.6  0.651  9.364   3.517  Urbaine    agressif
# 8855            29.0         17.3  0.655  8.938   3.729  Urbaine    agressif
# 8856            29.0         20.4  0.304  9.179   3.473  Urbaine    agressif
#
#                     time
# 0    2020-08-24 10:11:09
# 1    2020-08-24 10:11:13
# 2    2020-08-24 10:11:16
# 3    2020-08-24 10:11:20
# 4    2020-08-24 10:11:24
# ...                  ...
# 8852 2021-04-18 16:58:33
# 8853 2021-04-18 16:58:37
# 8854 2021-04-18 16:58:41
# 8855 2021-04-18 16:58:46
# 8856 2021-04-18 16:58:49
#
# [8857 rows x 14 columns]
# dropped segs (2300, 2364) (2365, 2484)
# dropped segs (2365, 2484) (2485, 2639)
# dropped segs (2485, 2639) (2640, 2860)
# dropped segs (2640, 2860) (2861, 2958)
# dropped segs (2861, 2958) (2959, 3107)
# dropped segs (2959, 3107) (3108, 3128)
# dropped segs (3108, 3128) (3129, 3267)
# dropped segs (3129, 3267) (3268, 3588)
# dropped segs (3268, 3588) (3589, 3845)
# dropped segs (3589, 3845) (3846, 3986)
# range(3987, 3990)
#       CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0       3  34.836142  10.755176    4.0      2357.0         34.5
# 1       3  34.836004  10.755005   24.0      3515.0         72.9
# 2       3  34.835828  10.754746   40.0      3213.0         94.9
# 3       3  34.835532  10.754236   52.0      2559.0         96.1
# 4       3  34.835464  10.753682   44.0      2126.0          0.0
# ...   ...        ...        ...    ...         ...          ...
# 8852    3  34.577476  10.584655   14.0       841.0         13.7
# 8853    3  34.577374  10.584555   15.0      1138.0         25.1
# 8854    3  34.577224  10.584422   18.0      1438.0         30.2
# 8855    3  34.576934  10.584160   29.0      2316.0         14.9
# 8856    3  34.576751  10.583980   30.0      2356.0         23.5
#
#       AmbientAirTemp  ThrottlePos   valX   valY    valZ     zone TargetValue  \
# 0               49.0         22.0 -0.468  5.105   8.536  Urbaine    agressif
# 1               49.0         39.6 -0.371  4.347   8.874  Urbaine    agressif
# 2               49.0         88.2 -0.225  3.594   8.585  Urbaine    agressif
# 3               49.0         88.2  1.334  1.295  10.185  Urbaine    agressif
# 4               49.0         16.1  0.155  4.378   8.993  Urbaine    agressif
# ...              ...          ...    ...    ...     ...      ...         ...
# 8852            29.0         13.7  0.418  9.375   4.206  Urbaine    agressif
# 8853            29.0         16.9  0.401  9.227   3.037  Urbaine    agressif
# 8854            29.0         28.6  0.651  9.364   3.517  Urbaine    agressif
# 8855            29.0         17.3  0.655  8.938   3.729  Urbaine    agressif
# 8856            29.0         20.4  0.304  9.179   3.473  Urbaine    agressif
#
#                     time
# 0    2020-08-24 10:11:09
# 1    2020-08-24 10:11:13
# 2    2020-08-24 10:11:16
# 3    2020-08-24 10:11:20
# 4    2020-08-24 10:11:24
# ...                  ...
# 8852 2021-04-18 16:58:33
# 8853 2021-04-18 16:58:37
# 8854 2021-04-18 16:58:41
# 8855 2021-04-18 16:58:46
# 8856 2021-04-18 16:58:49
#
# [8853 rows x 14 columns]
# dropped segs (3990, 4074) (4075, 4225)
# dropped segs (4075, 4225) (4226, 4253)
# dropped segs (4226, 4253) (4254, 4624)
# dropped segs (4254, 4624) (4625, 4753)
# range(4754, 4757)
#       CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0       3  34.836142  10.755176    4.0      2357.0         34.5
# 1       3  34.836004  10.755005   24.0      3515.0         72.9
# 2       3  34.835828  10.754746   40.0      3213.0         94.9
# 3       3  34.835532  10.754236   52.0      2559.0         96.1
# 4       3  34.835464  10.753682   44.0      2126.0          0.0
# ...   ...        ...        ...    ...         ...          ...
# 8852    3  34.577476  10.584655   14.0       841.0         13.7
# 8853    3  34.577374  10.584555   15.0      1138.0         25.1
# 8854    3  34.577224  10.584422   18.0      1438.0         30.2
# 8855    3  34.576934  10.584160   29.0      2316.0         14.9
# 8856    3  34.576751  10.583980   30.0      2356.0         23.5
#
#       AmbientAirTemp  ThrottlePos   valX   valY    valZ     zone TargetValue  \
# 0               49.0         22.0 -0.468  5.105   8.536  Urbaine    agressif
# 1               49.0         39.6 -0.371  4.347   8.874  Urbaine    agressif
# 2               49.0         88.2 -0.225  3.594   8.585  Urbaine    agressif
# 3               49.0         88.2  1.334  1.295  10.185  Urbaine    agressif
# 4               49.0         16.1  0.155  4.378   8.993  Urbaine    agressif
# ...              ...          ...    ...    ...     ...      ...         ...
# 8852            29.0         13.7  0.418  9.375   4.206  Urbaine    agressif
# 8853            29.0         16.9  0.401  9.227   3.037  Urbaine    agressif
# 8854            29.0         28.6  0.651  9.364   3.517  Urbaine    agressif
# 8855            29.0         17.3  0.655  8.938   3.729  Urbaine    agressif
# 8856            29.0         20.4  0.304  9.179   3.473  Urbaine    agressif
#
#                     time
# 0    2020-08-24 10:11:09
# 1    2020-08-24 10:11:13
# 2    2020-08-24 10:11:16
# 3    2020-08-24 10:11:20
# 4    2020-08-24 10:11:24
# ...                  ...
# 8852 2021-04-18 16:58:33
# 8853 2021-04-18 16:58:37
# 8854 2021-04-18 16:58:41
# 8855 2021-04-18 16:58:46
# 8856 2021-04-18 16:58:49
#
# [8850 rows x 14 columns]
# dropped segs (4757, 5021) (5022, 5066)
# dropped segs (5022, 5066) (5067, 5200)
# dropped segs (5067, 5200) (5201, 5394)
# dropped segs (5201, 5394) (5395, 5576)
# dropped segs (5395, 5576) (5577, 5728)
# dropped segs (5577, 5728) (5729, 6206)
# dropped segs (5729, 6206) (6207, 6360)
# dropped segs (6207, 6360) (6361, 6705)
# dropped segs (6361, 6705) (6706, 6978)
# dropped segs (6706, 6978) (6979, 7008)
# dropped segs (6979, 7008) (7009, 7081)
# range(7082, 7098)
#       CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0       3  34.836142  10.755176    4.0      2357.0         34.5
# 1       3  34.836004  10.755005   24.0      3515.0         72.9
# 2       3  34.835828  10.754746   40.0      3213.0         94.9
# 3       3  34.835532  10.754236   52.0      2559.0         96.1
# 4       3  34.835464  10.753682   44.0      2126.0          0.0
# ...   ...        ...        ...    ...         ...          ...
# 8852    3  34.577476  10.584655   14.0       841.0         13.7
# 8853    3  34.577374  10.584555   15.0      1138.0         25.1
# 8854    3  34.577224  10.584422   18.0      1438.0         30.2
# 8855    3  34.576934  10.584160   29.0      2316.0         14.9
# 8856    3  34.576751  10.583980   30.0      2356.0         23.5
#
#       AmbientAirTemp  ThrottlePos   valX   valY    valZ     zone TargetValue  \
# 0               49.0         22.0 -0.468  5.105   8.536  Urbaine    agressif
# 1               49.0         39.6 -0.371  4.347   8.874  Urbaine    agressif
# 2               49.0         88.2 -0.225  3.594   8.585  Urbaine    agressif
# 3               49.0         88.2  1.334  1.295  10.185  Urbaine    agressif
# 4               49.0         16.1  0.155  4.378   8.993  Urbaine    agressif
# ...              ...          ...    ...    ...     ...      ...         ...
# 8852            29.0         13.7  0.418  9.375   4.206  Urbaine    agressif
# 8853            29.0         16.9  0.401  9.227   3.037  Urbaine    agressif
# 8854            29.0         28.6  0.651  9.364   3.517  Urbaine    agressif
# 8855            29.0         17.3  0.655  8.938   3.729  Urbaine    agressif
# 8856            29.0         20.4  0.304  9.179   3.473  Urbaine    agressif
#
#                     time
# 0    2020-08-24 10:11:09
# 1    2020-08-24 10:11:13
# 2    2020-08-24 10:11:16
# 3    2020-08-24 10:11:20
# 4    2020-08-24 10:11:24
# ...                  ...
# 8852 2021-04-18 16:58:33
# 8853 2021-04-18 16:58:37
# 8854 2021-04-18 16:58:41
# 8855 2021-04-18 16:58:46
# 8856 2021-04-18 16:58:49
#
# [8847 rows x 14 columns]
# range(7171, 7173)
#       CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0       3  34.836142  10.755176    4.0      2357.0         34.5
# 1       3  34.836004  10.755005   24.0      3515.0         72.9
# 2       3  34.835828  10.754746   40.0      3213.0         94.9
# 3       3  34.835532  10.754236   52.0      2559.0         96.1
# 4       3  34.835464  10.753682   44.0      2126.0          0.0
# ...   ...        ...        ...    ...         ...          ...
# 8852    3  34.577476  10.584655   14.0       841.0         13.7
# 8853    3  34.577374  10.584555   15.0      1138.0         25.1
# 8854    3  34.577224  10.584422   18.0      1438.0         30.2
# 8855    3  34.576934  10.584160   29.0      2316.0         14.9
# 8856    3  34.576751  10.583980   30.0      2356.0         23.5
#
#       AmbientAirTemp  ThrottlePos   valX   valY    valZ     zone TargetValue  \
# 0               49.0         22.0 -0.468  5.105   8.536  Urbaine    agressif
# 1               49.0         39.6 -0.371  4.347   8.874  Urbaine    agressif
# 2               49.0         88.2 -0.225  3.594   8.585  Urbaine    agressif
# 3               49.0         88.2  1.334  1.295  10.185  Urbaine    agressif
# 4               49.0         16.1  0.155  4.378   8.993  Urbaine    agressif
# ...              ...          ...    ...    ...     ...      ...         ...
# 8852            29.0         13.7  0.418  9.375   4.206  Urbaine    agressif
# 8853            29.0         16.9  0.401  9.227   3.037  Urbaine    agressif
# 8854            29.0         28.6  0.651  9.364   3.517  Urbaine    agressif
# 8855            29.0         17.3  0.655  8.938   3.729  Urbaine    agressif
# 8856            29.0         20.4  0.304  9.179   3.473  Urbaine    agressif
#
#                     time
# 0    2020-08-24 10:11:09
# 1    2020-08-24 10:11:13
# 2    2020-08-24 10:11:16
# 3    2020-08-24 10:11:20
# 4    2020-08-24 10:11:24
# ...                  ...
# 8852 2021-04-18 16:58:33
# 8853 2021-04-18 16:58:37
# 8854 2021-04-18 16:58:41
# 8855 2021-04-18 16:58:46
# 8856 2021-04-18 16:58:49
#
# [8831 rows x 14 columns]
# dropped segs (7173, 7583) (7584, 7598)
# range(7599, 7602)
#       CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0       3  34.836142  10.755176    4.0      2357.0         34.5
# 1       3  34.836004  10.755005   24.0      3515.0         72.9
# 2       3  34.835828  10.754746   40.0      3213.0         94.9
# 3       3  34.835532  10.754236   52.0      2559.0         96.1
# 4       3  34.835464  10.753682   44.0      2126.0          0.0
# ...   ...        ...        ...    ...         ...          ...
# 8852    3  34.577476  10.584655   14.0       841.0         13.7
# 8853    3  34.577374  10.584555   15.0      1138.0         25.1
# 8854    3  34.577224  10.584422   18.0      1438.0         30.2
# 8855    3  34.576934  10.584160   29.0      2316.0         14.9
# 8856    3  34.576751  10.583980   30.0      2356.0         23.5
#
#       AmbientAirTemp  ThrottlePos   valX   valY    valZ     zone TargetValue  \
# 0               49.0         22.0 -0.468  5.105   8.536  Urbaine    agressif
# 1               49.0         39.6 -0.371  4.347   8.874  Urbaine    agressif
# 2               49.0         88.2 -0.225  3.594   8.585  Urbaine    agressif
# 3               49.0         88.2  1.334  1.295  10.185  Urbaine    agressif
# 4               49.0         16.1  0.155  4.378   8.993  Urbaine    agressif
# ...              ...          ...    ...    ...     ...      ...         ...
# 8852            29.0         13.7  0.418  9.375   4.206  Urbaine    agressif
# 8853            29.0         16.9  0.401  9.227   3.037  Urbaine    agressif
# 8854            29.0         28.6  0.651  9.364   3.517  Urbaine    agressif
# 8855            29.0         17.3  0.655  8.938   3.729  Urbaine    agressif
# 8856            29.0         20.4  0.304  9.179   3.473  Urbaine    agressif
#
#                     time
# 0    2020-08-24 10:11:09
# 1    2020-08-24 10:11:13
# 2    2020-08-24 10:11:16
# 3    2020-08-24 10:11:20
# 4    2020-08-24 10:11:24
# ...                  ...
# 8852 2021-04-18 16:58:33
# 8853 2021-04-18 16:58:37
# 8854 2021-04-18 16:58:41
# 8855 2021-04-18 16:58:46
# 8856 2021-04-18 16:58:49
#
# [8829 rows x 14 columns]
# range(7853, 7856)
#       CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0       3  34.836142  10.755176    4.0      2357.0         34.5
# 1       3  34.836004  10.755005   24.0      3515.0         72.9
# 2       3  34.835828  10.754746   40.0      3213.0         94.9
# 3       3  34.835532  10.754236   52.0      2559.0         96.1
# 4       3  34.835464  10.753682   44.0      2126.0          0.0
# ...   ...        ...        ...    ...         ...          ...
# 8852    3  34.577476  10.584655   14.0       841.0         13.7
# 8853    3  34.577374  10.584555   15.0      1138.0         25.1
# 8854    3  34.577224  10.584422   18.0      1438.0         30.2
# 8855    3  34.576934  10.584160   29.0      2316.0         14.9
# 8856    3  34.576751  10.583980   30.0      2356.0         23.5
#
#       AmbientAirTemp  ThrottlePos   valX   valY    valZ     zone TargetValue  \
# 0               49.0         22.0 -0.468  5.105   8.536  Urbaine    agressif
# 1               49.0         39.6 -0.371  4.347   8.874  Urbaine    agressif
# 2               49.0         88.2 -0.225  3.594   8.585  Urbaine    agressif
# 3               49.0         88.2  1.334  1.295  10.185  Urbaine    agressif
# 4               49.0         16.1  0.155  4.378   8.993  Urbaine    agressif
# ...              ...          ...    ...    ...     ...      ...         ...
# 8852            29.0         13.7  0.418  9.375   4.206  Urbaine    agressif
# 8853            29.0         16.9  0.401  9.227   3.037  Urbaine    agressif
# 8854            29.0         28.6  0.651  9.364   3.517  Urbaine    agressif
# 8855            29.0         17.3  0.655  8.938   3.729  Urbaine    agressif
# 8856            29.0         20.4  0.304  9.179   3.473  Urbaine    agressif
#
#                     time
# 0    2020-08-24 10:11:09
# 1    2020-08-24 10:11:13
# 2    2020-08-24 10:11:16
# 3    2020-08-24 10:11:20
# 4    2020-08-24 10:11:24
# ...                  ...
# 8852 2021-04-18 16:58:33
# 8853 2021-04-18 16:58:37
# 8854 2021-04-18 16:58:41
# 8855 2021-04-18 16:58:46
# 8856 2021-04-18 16:58:49
#
# [8826 rows x 14 columns]
# dropped segs (7856, 7871) (7872, 7885)
# range(7886, 7918)
#       CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0       3  34.836142  10.755176    4.0      2357.0         34.5
# 1       3  34.836004  10.755005   24.0      3515.0         72.9
# 2       3  34.835828  10.754746   40.0      3213.0         94.9
# 3       3  34.835532  10.754236   52.0      2559.0         96.1
# 4       3  34.835464  10.753682   44.0      2126.0          0.0
# ...   ...        ...        ...    ...         ...          ...
# 8852    3  34.577476  10.584655   14.0       841.0         13.7
# 8853    3  34.577374  10.584555   15.0      1138.0         25.1
# 8854    3  34.577224  10.584422   18.0      1438.0         30.2
# 8855    3  34.576934  10.584160   29.0      2316.0         14.9
# 8856    3  34.576751  10.583980   30.0      2356.0         23.5
#
#       AmbientAirTemp  ThrottlePos   valX   valY    valZ
# 3               49.0         15.7  0.098  3.335  9.258  Urbaine       timid
# 4               49.0         17.3  0.022  3.787  8.983  Urbaine       timid
# ...              ...          ...    ...    ...    ...      ...         ...
# 3513            34.0         19.6  0.284  9.259  3.583  Urbaine       timid
# 3514            34.0         19.6  0.315  9.205  3.484  Urbaine       timid
# 3515            34.0         19.6  0.193  9.221  3.584  Urbaine       timid
# 3516            34.0         17.3  0.103  9.049  3.594  Urbaine       timid
# 3517            34.0         19.2 -0.098  9.374  3.672  Urbaine       timid
#
#                     time
# 0    2020-08-24 10:34:10
# 1    2020-08-24 10:34:14
# 2    2020-08-24 10:34:17
# 3    2020-08-24 10:34:21
# 4    2020-08-24 10:34:24
# ...                  ...
# 3513 2021-04-18 12:06:08
# 3514 2021-04-18 12:06:12
# 3515 2021-04-18 12:06:16
# 3516 2021-04-18 12:06:20
# 3517 2021-04-18 12:06:24
#
# [3501 rows x 14 columns]
# dropped segs (2978, 3183) (3184, 3482)
# dropped segs (3184, 3482) (3483, 3517)

# %%
print(len(dangerous_trip_cleaned), len(agressif_trip_cleaned), len(timid_trip_cleaned), len(normal_trip_cleaned))
# Out:
# 3300 8790 3500 10470

# %%
trip_cleaned = pd.concat([timid_trip_cleaned, normal_trip_cleaned, agressif_trip_cleaned, dangerous_trip_cleaned], sort=False)

# %% [markdown]
# # Classification

# %% [markdown]
# ### Load preprocessed data shortcut file

# %%
len(trip_cleaned)
# Out:
# 26060

# %%
trip_cleaned.head()
# Out:
#    CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  AmbientAirTemp  \
# 0    1  34.835865  10.754808    0.0         0.0          0.0            49.0
# 1    1  34.835864  10.754808    0.0         0.0          0.0            49.0
# 2    1  34.835864  10.754808    0.0       992.0         10.6            49.0
# 3    1  34.835864  10.754808    0.0       893.0         23.1            49.0
# 4    1  34.835864  10.754808    1.0      1869.0         15.3            49.0
#
#    ThrottlePos   valX   valY   valZ     zone TargetValue                time
# 0         16.5  0.077  3.320  9.221  Urbaine       timid 2020-08-24 10:34:10
# 1         16.5  0.080  3.323  9.211  Urbaine       timid 2020-08-24 10:34:14
# 2         15.3  0.103  3.348  9.252  Urbaine       timid 2020-08-24 10:34:17
# 3         15.7  0.098  3.335  9.258  Urbaine       timid 2020-08-24 10:34:21
# 4         17.3  0.022  3.787  8.983  Urbaine       timid 2020-08-24 10:34:24

# %%
trip_cleaned.to_csv(r'local_database_preprocessed.csv', index=False)

# %%
data = pd.read_csv('local_database_preprocessed.csv')

# %%
data
#trip_cleaned = data(index=range(segments[][1]+1, segments[i+1][0] ), inplace=False)
# Out:
#        CIN   altitude  longitude  SPEED  ENGINE_RPM  ENGINE_LOAD  \
# 0        1  34.835865  10.754808    0.0         0.0          0.0
# 1        1  34.835864  10.754808    0.0         0.0          0.0
# 2        1  34.835864  10.754808    0.0       992.0         10.6
# 3        1  34.835864  10.754808    0.0       893.0         23.1
# 4        1  34.835864  10.754808    1.0      1869.0         15.3
# ...    ...        ...        ...    ...         ...          ...
# 26055    4  34.733033  10.717114   47.0      2273.0         59.2
# 26056    4  34.732676  10.715759    1.0      2310.0         62.4
# 26057    4  34.728577  10.715083   44.0      2208.0         20.0
# 26058    4  34.726142  10.715958    9.0      1133.0         34.9
# 26059    4  34.765743  10.652285   90.0      2535.0         43.9
#
#        AmbientAirTemp  ThrottlePos   valX   valY    valZ       zone  \
# 0                49.0         16.5  0.077  3.320   9.221    Urbaine
# 1                49.0         16.5  0.080  3.323   9.211    Urbaine
# 2                49.0         15.3  0.103  3.348   9.252    Urbaine
# 3                49.0         15.7  0.098  3.335   9.258    Urbaine
# 4                49.0         17.3  0.022  3.787   8.983    Urbaine
# ...               ...          ...    ...    ...     ...        ...
# 26055            36.0         25.5 -0.361  3.941   9.024    Urbaine
# 26056            34.0         16.9  0.171  1.517  10.257    Urbaine
# 26057            33.0         15.7  0.115  3.730   9.037    Urbaine
# 26058            34.0         18.0  0.216  2.047   9.647    Urbaine
# 26059            22.0         23.5  0.134  6.821   6.592  Nationale
#
#       TargetValue                 time
# 0           timid  2020-08-24 10:34:10
# 1           timid  2020-08-24 10:34:14
# 2           timid  2020-08-24 10:34:17
# 3           timid  2020-08-24 10:34:21
# 4           timid  2020-08-24 10:34:24
# ...           ...                  ...
# 26055   dangerous  2021-01-24 18:17:43
# 26056   dangerous  2021-01-24 18:18:19
# 26057   dangerous  2021-01-24 18:18:54
# 26058   dangerous  2021-01-24 18:19:29
# 26059   dangerous  2021-01-25 09:04:34
#
# [26060 rows x 14 columns]

# %%
import os
os.system('mkdir user1')
os.system('mkdir user2')
os.system('mkdir user3')
os.system('mkdir user4')
os.system('mkdir user5')
new_df=data.assign(trip_id=0)
dep=-1
arr=0
x1=0
x2=0
x3=0
x4=0
x5=0
for i in range(len(new_df)-1):
      if((Time_conv(new_df['time'] [i+1])-Time_conv(new_df['time'] [i])>30) or(new_df['CIN'] [i+1]!=new_df['CIN'] [i])):
            dep=arr
            arr=i
            print((dep,arr))
            
            new=new_df[dep+1:arr+1]
           
            if(new['CIN'][dep+1]==1):
                x1+=1
                os.system('echo.> user1/trip'+str(x1)+'.csv')
                new.to_csv('user1/trip'+str(x1)+'.csv', index=False)
            elif(new['CIN'][dep+1]==2):
                x2+=1
                os.system('echo.> user2/trip'+str(x1)+'.csv')
                new.to_csv('user2/trip'+str(x2)+'.csv', index=False)
            
            elif(new['CIN'][dep+1]==3):
                x3+=1
                os.system('echo.> user3/trip'+str(x1)+'.csv')
                new.to_csv('user3/trip'+str(x3)+'.csv', index=False)  
            elif(new['CIN'][dep+1]==4):
                x4+=1
                os.system('echo.> user4/trip'+str(x1)+'.csv')
                new.to_csv('user4/trip'+str(x4)+'.csv', index=False)
            elif(new['CIN'][dep+1]==5):
                x5+=1
                os.system('echo.> user5/trip'+str(x1)+'.csv')
                new.to_csv('user5/trip'+str(x5)+'.csv', index=False)
# Out:
# (0, 9)
# (9, 124)
# (124, 203)
# (203, 393)
# (393, 582)
# (582, 795)
# (795, 817)
# (817, 832)
